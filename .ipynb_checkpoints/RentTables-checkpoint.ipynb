# %% [markdown]
# ## Rentables for Project Comp257

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
plt.style.use('seaborn')
# %matplotlib inline

# %%
LGA = pd.read_excel('data/Rent-Tables-clean-Jun-Quarter-2019.xlsx', sheet_name= 0)
print("Shape of LGA: ",LGA.shape)
# Out:
# Shape of LGA:  (33067, 15)

# %%
LGA.replace(to_replace="-",value=10,inplace=True)
LGA.replace(to_replace="s",value=30,inplace=True)
LGA.head(200)
# Out:
#     GMR (Greater Metropolitan Region) Greater Sydney  Rings  \
# 0                               Total          Total  Total
# 1                               Total          Total  Total
# 2                               Total          Total  Total
# 3                               Total          Total  Total
# 4                               Total          Total  Total
# ..                                ...            ...    ...
# 195                             Total          Total  Total
# 196                             Total          Total  Total
# 197                             Total          Total  Total
# 198                             Total          Total  Total
# 199                             Total          Total  Total
#
#     LGA (Local Government Areas) Dwelling Types Bedroom Numbers  \
# 0                          Total          Total           Total
# 1                          Total          Total       Bedsitter
# 2                          Total          Total       1 Bedroom
# 3                          Total          Total   Not Specified
# 4                          Total          Total      2 Bedrooms
# ..                           ...            ...             ...
# 195                      Bayside          Total           Total
# 196                      Bayside          Total       Bedsitter
# 197                      Bayside          Total       1 Bedroom
# 198                      Bayside          Total   Not Specified
# 199                      Bayside          Total      2 Bedrooms
#
#      First Quartile Weekly Rent for New Bonds\n$  \
# 0                                            375
# 1                                            315
# 2                                            340
# 3                                            350
# 4                                            360
# ..                                           ...
# 195                                          470
# 196                                          376
# 197                                          460
# 198                                          395
# 199                                          450
#
#      Median Weekly Rent for New Bonds\n$  \
# 0                                    475
# 1                                    390
# 2                                    450
# 3                                    440
# 4                                    465
# ..                                   ...
# 195                                  570
# 196                                  423
# 197                                  530
# 198                                  510
# 199                                  555
#
#      Third Quartile Weekly Rent for New Bonds\n$  New Bonds Lodged\nNo.  \
# 0                                            600                  74871
# 1                                            465                    860
# 2                                            550                  12637
# 3                                            560                   2796
# 4                                            610                  27859
# ..                                           ...                    ...
# 195                                          699                   2173
# 196                                          451                     30
# 197                                          580                    437
# 198                                          621                     52
# 199                                          680                   1231
#
#      Total Bonds Held\nNo.  Quarterly change in Median Weekly Rent  \
# 0                   764400                                 -0.0104
# 1                     8880                                 -0.0488
# 2                   105243                                 -0.0217
# 3                    57312                                  0.0115
# 4                   278716                                 -0.0510
# ..                     ...                                     ...
# 195                  22864                                 -0.0500
# 196                    103                                  0.0833
# 197                   3591                                  0.0000
# 198                   1336                                 -0.0286
# 199                  12694                                 -0.0750
#
#      Annual change in Median Weekly Rent  \
# 0                                -0.0104
# 1                                 0.0000
# 2                                -0.0217
# 3                                -0.0414
# 4                                -0.0312
# ..                                   ...
# 195                              -0.0256
# 196                              -0.1244
# 197                               0.0000
# 198                              -0.0097
# 199                              -0.0263
#
#      Quarterly change in New Bonds Lodged  Annual change in New Bonds Lodged
# 0                                 -0.0778                             0.0240
# 1                                 -0.1739                            -0.1088
# 2                                 -0.1416                             0.0235
# 3                                 -0.0729                            -0.2183
# 4                                 -0.0779                             0.0655
# ..                                    ...                                ...
# 195                               -0.1545                             0.1030
# 196                                0.5556                             0.7500
# 197                               -0.1312                             0.0505
# 198                               -0.1034                            -0.2239
# 199                               -0.1475                             0.1986
#
# [200 rows x 15 columns]

# %%
postcode = pd.read_excel('data/Rent-Tables-clean-Jun-Quarter-2019.xlsx', sheet_name=1)

# %%
postcode.replace(to_replace="-",value=10,inplace=True)
postcode.replace(to_replace="s",value=30,inplace=True)
print("Shape of postcode: ",postcode.shape)
postcode.head()
# Out:
# Shape of postcode:  (16481, 12)
#    Postcode Dwelling Types Bedroom Numbers  \
# 0      1360          Total           Total
# 1      1360          Total      2 Bedrooms
# 2      1360      Flat/Unit           Total
# 3      1360      Flat/Unit      2 Bedrooms
# 4      1790          Total           Total
#
#    First Quartile Weekly Rent for New Bonds\n$  \
# 0                                           10
# 1                                           10
# 2                                           10
# 3                                           10
# 4                                           10
#
#    Median Weekly Rent for New Bonds\n$  \
# 0                                   10
# 1                                   10
# 2                                   10
# 3                                   10
# 4                                   10
#
#    Third Quartile Weekly Rent for New Bonds\n$  New Bonds Lodged\nNo.  \
# 0                                           10                     10
# 1                                           10                     10
# 2                                           10                     10
# 3                                           10                     10
# 4                                           10                     10
#
#    Total Bonds Held\nNo.  Quarterly change in Median Weekly Rent  \
# 0                     10                                    10.0
# 1                     10                                    10.0
# 2                     10                                    10.0
# 3                     10                                    10.0
# 4                     10                                    10.0
#
#    Annual change in Median Weekly Rent  Quarterly change in New Bonds Lodged  \
# 0                                 10.0                                  10.0
# 1                                 10.0                                  10.0
# 2                                 10.0                                  10.0
# 3                                 10.0                                  10.0
# 4                                 10.0                                  10.0
#
#    Annual change in New Bonds Lodged
# 0                               10.0
# 1                               10.0
# 2                               10.0
# 3                               10.0
# 4                               10.0

# %%
LGA.dtypes
# Out:
# GMR (Greater Metropolitan Region)               object
# Greater Sydney                                  object
# Rings                                           object
# LGA (Local Government Areas)                    object
# Dwelling Types                                  object
# Bedroom Numbers                                 object
# First Quartile Weekly Rent for New Bonds\n$      int64
# Median Weekly Rent for New Bonds\n$              int64
# Third Quartile Weekly Rent for New Bonds\n$      int64
# New Bonds Lodged\nNo.                            int64
# Total Bonds Held\nNo.                            int64
# Quarterly change in Median Weekly Rent         float64
# Annual change in Median Weekly Rent            float64
# Quarterly change in New Bonds Lodged           float64
# Annual change in New Bonds Lodged              float64
# dtype: object

# %%
LGA.columns
# Out:
# Index(['GMR (Greater Metropolitan Region)', 'Greater Sydney', 'Rings',
#        'LGA (Local Government Areas)', 'Dwelling Types', 'Bedroom Numbers',
#        'First Quartile Weekly Rent for New Bonds\n$',
#        'Median Weekly Rent for New Bonds\n$',
#        'Third Quartile Weekly Rent for New Bonds\n$', 'New Bonds Lodged\nNo.',
#        'Total Bonds Held\nNo.', 'Quarterly change in Median Weekly Rent',
#        'Annual change in Median Weekly Rent',
#        'Quarterly change in New Bonds Lodged',
#        'Annual change in New Bonds Lodged'],
#       dtype='object')

# %%
LGA.rename(columns={'GMR (Greater Metropolitan Region)':'GMR',
                    'Greater Sydney':'Greater_Sydney',
                    'LGA (Local Government Areas)':'LGA',
                    'Dwelling Types':'Dwelling_Types',
                    'Bedroom Numbers':'Bedroom_Numbers'},
           inplace=True)

# %% [markdown]
# ### Renaming Columns and determinig correlation

# %%
LGA_clean =  LGA[LGA.Bedroom_Numbers != 'Total']

# %%
LGA_clean =  LGA_clean[LGA_clean.Dwelling_Types != 'Total']

# %%
LGA_clean = LGA_clean[LGA_clean.LGA != 'Total']

# %%
LGA_clean.shape
# Out:
# (20848, 15)

# %%
g = sns.pairplot(LGA_clean,vars=['First Quartile Weekly Rent for New Bonds\n$',
       'Median Weekly Rent for New Bonds\n$',
       'Third Quartile Weekly Rent for New Bonds\n$', 'New Bonds Lodged\nNo.',
       'Total Bonds Held\nNo.'],hue='Dwelling_Types')

# %%
g = sns.pairplot(LGA_clean,vars=['First Quartile Weekly Rent for New Bonds\n$',
       'Median Weekly Rent for New Bonds\n$',
       'Third Quartile Weekly Rent for New Bonds\n$', 'New Bonds Lodged\nNo.',
       'Total Bonds Held\nNo.'], hue='Bedroom_Numbers')

# %%
g = sns.pairplot(LGA_clean,vars=['First Quartile Weekly Rent for New Bonds\n$',
       'Median Weekly Rent for New Bonds\n$',
       'Third Quartile Weekly Rent for New Bonds\n$', 'New Bonds Lodged\nNo.',
       'Total Bonds Held\nNo.'], hue='Rings')

# %%
LGA_clean.describe()
# Out:
#        First Quartile Weekly Rent for New Bonds\n$  \
# count                                 20848.000000
# mean                                    127.384881
# std                                     209.315538
# min                                      10.000000
# 25%                                      10.000000
# 50%                                      10.000000
# 75%                                     250.000000
# max                                    1550.000000
#
#        Median Weekly Rent for New Bonds\n$  \
# count                         20848.000000
# mean                            144.294705
# std                             242.789895
# min                              10.000000
# 25%                              10.000000
# 50%                              10.000000
# 75%                             280.000000
# max                            2175.000000
#
#        Third Quartile Weekly Rent for New Bonds\n$  New Bonds Lodged\nNo.  \
# count                                  20848.00000           20848.000000
# mean                                     164.21604              35.909823
# std                                      285.68111             106.954060
# min                                       10.00000              10.000000
# 25%                                       10.00000              10.000000
# 50%                                       10.00000              10.000000
# 75%                                      310.00000              30.000000
# max                                     3000.00000            2571.000000
#
#        Total Bonds Held\nNo.  Quarterly change in Median Weekly Rent  \
# count           20848.000000                            20832.000000
# mean              297.019186                                7.058049
# std               998.913554                                4.558111
# min                10.000000                               -0.872100
# 25%                10.000000                                0.044400
# 50%                35.000000                               10.000000
# 75%               172.000000                               10.000000
# max             19439.000000                               10.000000
#
#        Annual change in Median Weekly Rent  \
# count                         20840.000000
# mean                              7.053787
# std                               4.561163
# min                              -0.862500
# 25%                               0.060600
# 50%                              10.000000
# 75%                              10.000000
# max                              10.000000
#
#        Quarterly change in New Bonds Lodged  Annual change in New Bonds Lodged
# count                          20832.000000                       20840.000000
# mean                               7.081812                           7.100564
# std                                4.527474                           4.525275
# min                               -0.721500                          -0.705100
# 25%                                0.387825                           0.375000
# 50%                               10.000000                          10.000000
# 75%                               10.000000                          10.000000
# max                               10.000000                          25.000000

# %%
LGA_clean1 = LGA_clean.drop(["Quarterly change in Median Weekly Rent", "Annual change in Median Weekly Rent", "Quarterly change in New Bonds Lodged", "Annual change in New Bonds Lodged"], axis =1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
modelLog = LogisticRegression()

# %%
train, test = train_test_split(LGA_clean1,test_size = 0.3,random_state = 142)

# %%
LGA_clean1.columns
# Out:
# Index(['GMR', 'Greater_Sydney', 'Rings', 'LGA', 'Dwelling_Types',
#        'Bedroom_Numbers', 'First Quartile Weekly Rent for New Bonds\n$',
#        'Median Weekly Rent for New Bonds\n$',
#        'Third Quartile Weekly Rent for New Bonds\n$', 'New Bonds Lodged\nNo.',
#        'Total Bonds Held\nNo.'],
#       dtype='object')

# %%
x_train = train.drop(['GMR',
                      'Greater_Sydney',
                      'Rings',
                      'LGA',
                      'Dwelling_Types',
                      'Bedroom_Numbers'],
                     axis = 1)
y_train = train.drop(['GMR',
                      'Greater_Sydney',
                      'Rings','Dwelling_Types',
                      'Bedroom_Numbers', 
                      'First Quartile Weekly Rent for New Bonds\n$',
                      'Median Weekly Rent for New Bonds\n$',
                      'Third Quartile Weekly Rent for New Bonds\n$', 
                      'New Bonds Lodged\nNo.','Total Bonds Held\nNo.'],
                     axis = 1)
x_test = test.drop(['GMR',
                    'Greater_Sydney',
                    'Rings',
                    'LGA',
                    'Dwelling_Types',
                   'Bedroom_Numbers'],
                   axis = 1)
y_test = test.drop(['GMR',
                      'Greater_Sydney',
                      'Rings','Dwelling_Types',
                    'Bedroom_Numbers',
                    'First Quartile Weekly Rent for New Bonds\n$',
                    'Median Weekly Rent for New Bonds\n$',
                    'Third Quartile Weekly Rent for New Bonds\n$',
                    'New Bonds Lodged\nNo.',
                    'Total Bonds Held\nNo.'],
                   axis = 1)
print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
# Out:
# (14593, 5) (14593, 1) (6255, 5) (6255, 1)

# %%
modelLog.fit(x_train, y_train)
# Out:
# C:\Users\mukit\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\mukit\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\mukit\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\Users\mukit\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = modelLog.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.016466826538768985

# %%
#Removing warnings
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
from sklearn.feature_selection import RFE
modelRFE = LogisticRegression()
selector = RFE(modelRFE, 4 ,step=1)
selector.fit(x_train, y_train)
y_pred = selector.predict(x_test)
print("acc on 4 features",accuracy_score(y_test,y_pred))
print(selector.support_)
col_names = x_train.columns
print(col_names[selector.support_])
# Out:
# C:\Users\mukit\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\mukit\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# acc on 4 features 0.019504396482813748
# [ True  True  True  True False]
# Index(['First Quartile Weekly Rent for New Bonds\n$',
#        'Median Weekly Rent for New Bonds\n$',
#        'Third Quartile Weekly Rent for New Bonds\n$', 'New Bonds Lodged\nNo.'],
#       dtype='object')
# C:\Users\mukit\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
modelRFE = LogisticRegression()
selector = RFE(modelRFE, 3 ,step=1)
selector.fit(x_train, y_train)
y_pred = selector.predict(x_test)
print("acc on 3 features",accuracy_score(y_test,y_pred))
# Out:
# C:\Users\mukit\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\mukit\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\mukit\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# acc on 3 features 0.02238209432454037

# %%
modelRFE = LogisticRegression()
selector = RFE(modelRFE, 2 ,step=1)
selector.fit(x_train, y_train)
y_pred = selector.predict(x_test)
print("acc on 2 features",accuracy_score(y_test,y_pred))
# Out:
# C:\Users\mukit\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\mukit\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\mukit\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# acc on 2 features 0.016147082334132694

# %%
modelRFE = LogisticRegression()
selector = RFE(modelRFE, 1 ,step=1)
selector.fit(x_train, y_train)
y_pred = selector.predict(x_test)
print("acc on 1 features",accuracy_score(y_test,y_pred))
# Out:
# C:\Users\mukit\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\mukit\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\mukit\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# acc on 1 features 0.011510791366906475

# %%
x_train = train.drop(['GMR',
                      'Greater_Sydney',
                      'Rings',
                      'LGA',
                      'Dwelling_Types',
                      'Bedroom_Numbers'],
                     axis = 1)
y_train = train['Dwelling_Types']
x_test = test.drop(['GMR',
                    'Greater_Sydney',
                    'Rings',
                    'LGA',
                    'Dwelling_Types',
                   'Bedroom_Numbers'],
                   axis = 1)
y_test = test['Dwelling_Types']
print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
# Out:
# (14593, 5) (14593,) (6255, 5) (6255,)

# %%
modelRFE = LogisticRegression()
selector = RFE(modelRFE, 1 ,step=1)
selector.fit(x_train, y_train)
y_pred = selector.predict(x_test)
print("acc on 1 features",accuracy_score(y_test,y_pred))
# Out:
# acc on 1 features 0.31366906474820144

# %%
x_train = train.drop(['GMR',
                      'Greater_Sydney',
                      'Rings',
                      'LGA',
                      'Dwelling_Types',
                      'Bedroom_Numbers'],
                     axis = 1)
y_train = train['Dwelling_Types']
x_test = test.drop(['GMR',
                    'Greater_Sydney',
                    'Rings',
                    'LGA',
                    'Dwelling_Types',
                   'Bedroom_Numbers'],
                   axis = 1)
y_test = test['Dwelling_Types']
print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
# Out:
# (14593, 5) (14593,) (6255, 5) (6255,)

# %%
dwelling_types = test['Dwelling_Types']
y_test = pd.get_dummies(dwelling_types)
y_test.head()
# Out:
#        Flat/Unit  House  Other  Townhouse
# 23626          0      0      1          0
# 10327          0      0      0          1
# 14652          0      0      0          1
# 3616           0      1      0          0
# 12479          1      0      0          0

# %%
dwelling_types = train['Dwelling_Types']
y_train= pd.get_dummies(dwelling_types)
y_train.head()
# Out:
#        Flat/Unit  House  Other  Townhouse
# 1504           0      1      0          0
# 11192          1      0      0          0
# 32393          0      1      0          0
# 25006          1      0      0          0
# 6825           1      0      0          0

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
import numpy as np
import math 
def mape(y_true,y_pred):
    return np.mean(np.abs((y_true - y_pred)/ y_true))*100

# %%
model = LinearRegression()
model.fit(x_train, dwelling_types_train)
y_train_pred = model.predict(x_train)
print("Checking training values")
print("RMSC: ", math.sqrt(mean_squared_error(y_train,y_train_pred)))
print("R2: ", r2_score(y_train,y_train_pred))
print("MAE: ", mean_absolute_error(y_train,y_train_pred))
# Out:
# Checking training values
# RMSC:  0.4250787775867333
# R2:  0.030317031998015193
# MAE:  0.36349301041693505

# %%
y_test_pred = model.predict(x_test)
print("Checking testing values")
print("MSE: ", mean_squared_error(y_test,y_test_pred))
print("R2: ", r2_score(y_test,y_test_pred))
print("MAE: ", mean_absolute_error(y_test,y_test_pred))
# Out:
# Checking testing values
# MSE:  0.18047845925110978
# R2:  0.032380929674824005
# MAE:  0.36312254772451524

# %%
train, test = train_test_split(LGA_clean1,test_size = 0.2,random_state = 142)
x_train = train.drop(['GMR',
                      'Greater_Sydney',
                      'Rings',
                      'LGA',
                      'Dwelling_Types',
                      'Bedroom_Numbers'],
                     axis = 1)
y_train = train['Dwelling_Types']
x_test = test.drop(['GMR',
                    'Greater_Sydney',
                    'Rings',
                    'LGA',
                    'Dwelling_Types',
                   'Bedroom_Numbers'],
                   axis = 1)
y_test = test['Dwelling_Types']
print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
# Out:
# (16678, 5) (16678,) (4170, 5) (4170,)

# %%
from sklearn.tree import DecisionTreeClassifier
model  = DecisionTreeClassifier(random_state=0)
model.fit(x_train, y_train)
y_pred =  model.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.5693045563549161

# %%
model  = DecisionTreeClassifier(random_state=0,max_depth=4)
model.fit(x_train, y_train)
y_pred =  model.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.36810551558752996

# %%
model  = DecisionTreeClassifier(random_state=0,max_depth=8)
model.fit(x_train, y_train)
y_pred =  model.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.437410071942446

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=3)
model.fit(x_train, y_train)
y_pred =  model.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.5517985611510792

# %%
model = KNeighborsClassifier(n_neighbors=9)
model.fit(x_train, y_train)
y_pred =  model.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.5211031175059953

# %% [markdown]
# ### Data Cleaning postcode dataframe

# %%
postcode.rename(columns={'Bedroom Numbers':'Bedroom_Numbers'}, inplace=True)

# %%
postcode.rename(columns={'Dwelling Types':'Dwelling_Types'}, inplace=True)

# %%
postcode_clean =  postcode[postcode.Bedroom_Numbers != 'Total']

# %%
postcode_clean =  postcode_clean[postcode.Dwelling_Types != 'Total']
# Out:
# C:\Users\mukit\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
print(postcode_clean.shape)
postcode_clean.head(200)
# Out:
# (10291, 12)
#      Postcode Dwelling_Types Bedroom_Numbers  \
# 3        1360      Flat/Unit      2 Bedrooms
# 7        1790      Flat/Unit      2 Bedrooms
# 11       1825          Other      2 Bedrooms
# 15       1860      Townhouse      3 Bedrooms
# 19       1871          Other   Not Specified
# ..        ...            ...             ...
# 307      2017          Other       Bedsitter
# 308      2017          Other       1 Bedroom
# 309      2017          Other   Not Specified
# 310      2017          Other      2 Bedrooms
# 311      2017          Other      3 Bedrooms
#
#      First Quartile Weekly Rent for New Bonds\n$  \
# 3                                             10
# 7                                             10
# 11                                            10
# 15                                            10
# 19                                            10
# ..                                           ...
# 307                                           10
# 308                                           10
# 309                                           10
# 310                                           10
# 311                                           10
#
#      Median Weekly Rent for New Bonds\n$  \
# 3                                     10
# 7                                     10
# 11                                    10
# 15                                    10
# 19                                    10
# ..                                   ...
# 307                                   10
# 308                                   10
# 309                                   10
# 310                                   10
# 311                                   10
#
#      Third Quartile Weekly Rent for New Bonds\n$  New Bonds Lodged\nNo.  \
# 3                                             10                     10
# 7                                             10                     10
# 11                                            10                     10
# 15                                            10                     10
# 19                                            10                     10
# ..                                           ...                    ...
# 307                                           10                     10
# 308                                           10                     10
# 309                                           10                     10
# 310                                           10                     10
# 311                                           10                     10
#
#      Total Bonds Held\nNo.  Quarterly change in Median Weekly Rent  \
# 3                       10                                    10.0
# 7                       10                                    10.0
# 11                      10                                    10.0
# 15                      10                                    10.0
# 19                      10                                    10.0
# ..                     ...                                     ...
# 307                     10                                    10.0
# 308                     51                                    10.0
# 309                     91                                    10.0
# 310                    128                                    10.0
# 311                     30                                    10.0
#
#      Annual change in Median Weekly Rent  \
# 3                                   10.0
# 7                                   10.0
# 11                                  10.0
# 15                                  10.0
# 19                                  10.0
# ..                                   ...
# 307                                 10.0
# 308                                 10.0
# 309                                 10.0
# 310                                 10.0
# 311                                 10.0
#
#      Quarterly change in New Bonds Lodged  Annual change in New Bonds Lodged
# 3                                    10.0                               10.0
# 7                                    10.0                               10.0
# 11                                   10.0                               10.0
# 15                                   10.0                               10.0
# 19                                   10.0                               10.0
# ..                                    ...                                ...
# 307                                  10.0                               10.0
# 308                                  10.0                               10.0
# 309                                  10.0                               10.0
# 310                                  10.0                               10.0
# 311                                  10.0                               10.0
#
# [200 rows x 12 columns]

# %%
postcode_clean.columns
# Out:
# Index(['Postcode', 'Dwelling_Types', 'Bedroom_Numbers',
#        'First Quartile Weekly Rent for New Bonds\n$',
#        'Median Weekly Rent for New Bonds\n$',
#        'Third Quartile Weekly Rent for New Bonds\n$', 'New Bonds Lodged\nNo.',
#        'Total Bonds Held\nNo.', 'Quarterly change in Median Weekly Rent',
#        'Annual change in Median Weekly Rent',
#        'Quarterly change in New Bonds Lodged',
#        'Annual change in New Bonds Lodged'],
#       dtype='object')

# %%
g = sns.pairplot(postcode_clean,vars=['First Quartile Weekly Rent for New Bonds\n$',
       'Median Weekly Rent for New Bonds\n$',
       'Third Quartile Weekly Rent for New Bonds\n$', 'New Bonds Lodged\nNo.',
       'Total Bonds Held\nNo.'],hue='Dwelling_Types')

# %%
g = sns.pairplot(postcode_clean,vars=['First Quartile Weekly Rent for New Bonds\n$',
       'Median Weekly Rent for New Bonds\n$',
       'Third Quartile Weekly Rent for New Bonds\n$', 'New Bonds Lodged\nNo.',
       'Total Bonds Held\nNo.'],hue='Bedroom_Numbers')

# %%
dfNB= postcode_clean['New Bonds Lodged\nNo.']
dfNB.plot.hist()

# %%
postcode_clean.describe()
# Out:
#            Postcode  First Quartile Weekly Rent for New Bonds\n$  \
# count  10291.000000                                 10291.000000
# mean    2374.929550                                    76.600913
# std      278.292417                                   178.654555
# min     1360.000000                                    10.000000
# 25%     2142.000000                                    10.000000
# 50%     2320.000000                                    10.000000
# 75%     2570.000000                                    10.000000
# max     5341.000000                                  1875.000000
#
#        Median Weekly Rent for New Bonds\n$  \
# count                         10291.000000
# mean                             84.319114
# std                             201.511712
# min                              10.000000
# 25%                              10.000000
# 50%                              10.000000
# 75%                              10.000000
# max                            2225.000000
#
#        Third Quartile Weekly Rent for New Bonds\n$  New Bonds Lodged\nNo.  \
# count                                  10291.00000           10291.000000
# mean                                      92.90720              15.629288
# std                                      227.92524              22.898926
# min                                       10.00000              10.000000
# 25%                                       10.00000              10.000000
# 50%                                       10.00000              10.000000
# 75%                                       10.00000              10.000000
# max                                     3000.00000             544.000000
#
#        Total Bonds Held\nNo.  Quarterly change in Median Weekly Rent  \
# count           10291.000000                            10289.000000
# mean               79.421631                                8.558095
# std               221.271911                                3.514123
# min                10.000000                               -0.350600
# 25%                10.000000                               10.000000
# 50%                30.000000                               10.000000
# 75%                53.000000                               10.000000
# max              5289.000000                               10.000000
#
#        Annual change in Median Weekly Rent  \
# count                         10289.000000
# mean                              8.557565
# std                               3.515231
# min                              -0.450000
# 25%                              10.000000
# 50%                              10.000000
# 75%                              10.000000
# max                              10.000000
#
#        Quarterly change in New Bonds Lodged  Annual change in New Bonds Lodged
# count                          10289.000000                       10289.000000
# mean                               8.579208                           8.595388
# std                                3.472402                           3.433147
# min                               -0.863600                          -0.924200
# 25%                               10.000000                          10.000000
# 50%                               10.000000                          10.000000
# 75%                               10.000000                          10.000000
# max                               12.000000                          10.000000

# %%
postcode_clean.columns
# Out:
# Index(['Postcode', 'Dwelling_Types', 'Bedroom_Numbers',
#        'First Quartile Weekly Rent for New Bonds\n$',
#        'Median Weekly Rent for New Bonds\n$',
#        'Third Quartile Weekly Rent for New Bonds\n$', 'New Bonds Lodged\nNo.',
#        'Total Bonds Held\nNo.', 'Quarterly change in Median Weekly Rent',
#        'Annual change in Median Weekly Rent',
#        'Quarterly change in New Bonds Lodged',
#        'Annual change in New Bonds Lodged'],
#       dtype='object')

# %%
postcode_clean1= postcode_clean.drop(['Quarterly change in Median Weekly Rent',
       'Annual change in Median Weekly Rent',
       'Quarterly change in New Bonds Lodged',
       'Annual change in New Bonds Lodged'],axis=1)

# %%
postcode_clean1.columns
# Out:
# Index(['Postcode', 'Dwelling_Types', 'Bedroom_Numbers',
#        'First Quartile Weekly Rent for New Bonds\n$',
#        'Median Weekly Rent for New Bonds\n$',
#        'Third Quartile Weekly Rent for New Bonds\n$', 'New Bonds Lodged\nNo.',
#        'Total Bonds Held\nNo.'],
#       dtype='object')

# %%
train, test = train_test_split(postcode_clean1,test_size = 0.3,random_state = 142)
x_train = train.drop([ 'Dwelling_Types', 'Bedroom_Numbers'],axis=1)
y_train = train['Dwelling_Types']
x_test = test.drop([ 'Dwelling_Types', 'Bedroom_Numbers'],axis=1)
y_test = test['Dwelling_Types']
print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
# Out:
# (7203, 6) (7203,) (3088, 6) (3088,)

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.3400259067357513

# %%
from sklearn.feature_selection import RFE
modelRFE = LogisticRegression()
selector = RFE(modelRFE, 4 ,step=1)
selector.fit(x_train, y_train)
y_pred = selector.predict(x_test)
print("acc on 4 features",accuracy_score(y_test,y_pred))
# Out:
# acc on 4 features 0.33613989637305697

# %%
modelRFE = LogisticRegression()
selector = RFE(modelRFE, 3 ,step=1)
selector.fit(x_train, y_train)
y_pred = selector.predict(x_test)
print("acc on 3 features",accuracy_score(y_test,y_pred))
# Out:
# acc on 3 features 0.33613989637305697

# %%
modelRFE = LogisticRegression()
selector = RFE(modelRFE, 2 ,step=1)
selector.fit(x_train, y_train)
y_pred = selector.predict(x_test)
print("acc on 2 features",accuracy_score(y_test,y_pred))
# Out:
# acc on 2 features 0.33419689119170987

# %%
from sklearn.tree import DecisionTreeClassifier
model  = DecisionTreeClassifier(random_state=0)
model.fit(x_train, y_train)
y_pred =  model.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.2655440414507772

# %%
from sklearn.tree import DecisionTreeClassifier
model  = DecisionTreeClassifier(random_state=0,max_depth=2)
model.fit(x_train, y_train)
y_pred =  model.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.33031088082901555

# %%
model  = DecisionTreeClassifier(random_state=0,max_depth=4)
model.fit(x_train, y_train)
y_pred =  model.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.35751295336787564

# %%
model  = DecisionTreeClassifier(random_state=0,max_depth=8)
model.fit(x_train, y_train)
y_pred =  model.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.3539507772020725

# %%
model = KNeighborsClassifier(n_neighbors=9)
model.fit(x_train, y_train)
y_pred =  model.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.3005181347150259

# %%
model = KNeighborsClassifier(n_neighbors=3)
model.fit(x_train, y_train)
y_pred =  model.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.280440414507772
