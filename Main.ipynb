# %%
import pandas as pd
import seaborn as sns 
import numpy as np
import matplotlib.pyplot as plt
import warnings
# %matplotlib inline
from pandas import ExcelWriter
from pandas import ExcelFile

# %% [markdown]
# #Removing warnings
# warnings.filterwarnings("ignore", category=FutureWarning)

# %%
StateResidence = pd.read_excel("data/snapshot_clean.xlsx", sheet_name = 0 )
StateResidence
# Out:
#    Year  New South Wales  Victoria  Queensland  South Australia  \
# 0  1966          4237900   3220217     1674324          1094984
# 1  1991          5714974   4287877     2887505          1408623
# 2  2006          6549174   4932421     3904531          1514340
# 3  2011          6917656   5354040     4332738          1596570
# 4  2016          7480228   5926624     4703193          1676653
#
#    Western Australia  Tasmania  Northern Territory  \
# 0             848100    371436               56504
# 1            1576334    456219              159300
# 2            1959087    476481              192899
# 3            2239171    495352              211944
# 4            2474410    509965              228833
#
#    Australian Capital Territory     Total
# 0                         96032  11599497
# 1                        280868  16771700
# 2                        324034  19855288
# 3                        357218  21507717
# 4                        397397  23401892
