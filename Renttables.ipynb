# %% [markdown]
# Rent Table for Project Comp257

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
plt.style.use('seaborn')
# %matplotlib inline

# %%
LGA = pd.read_excel('data/Rent-Tables-Jun-Quarter-2019.xlsx', sheet_name= 0)

# %%
postcode = pd.read_excel('data/Rent-Tables-Jun-Quarter-2019.xlsx', sheet_name=1)

# %%
LGA.shape
# Out:
# (33067, 15)

# %%
postcode.shape
# Out:
# (16481, 12)

# %%
LGA.replace(to_replace="-",value="",inplace=True)

# %%
LGA.head(100)
# Out:
#    GMR (Greater Metropolitan Region) Greater Sydney  Rings  \
# 0                              Total          Total  Total
# 1                              Total          Total  Total
# 2                              Total          Total  Total
# 3                              Total          Total  Total
# 4                              Total          Total  Total
# ..                               ...            ...    ...
# 95                             Total          Total  Total
# 96                             Total          Total  Total
# 97                             Total          Total  Total
# 98                             Total          Total  Total
# 99                             Total          Total  Total
#
#    LGA (Local Government Areas) Dwelling Types     Bedroom Numbers  \
# 0                         Total          Total               Total
# 1                         Total          Total           Bedsitter
# ...

# %%
LGA.dtypes
# Out:
# GMR (Greater Metropolitan Region)              object
# Greater Sydney                                 object
# Rings                                          object
# LGA (Local Government Areas)                   object
# Dwelling Types                                 object
# Bedroom Numbers                                object
# First Quartile Weekly Rent for New Bonds\n$    object
# Median Weekly Rent for New Bonds\n$            object
# Third Quartile Weekly Rent for New Bonds\n$    object
# New Bonds Lodged\nNo.                          object
# Total Bonds Held\nNo.                          object
# Quarterly change in Median Weekly Rent         object
# Annual change in Median Weekly Rent            object
# Quarterly change in New Bonds Lodged           object
# Annual change in New Bonds Lodged              object
# dtype: object
