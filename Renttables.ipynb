# %% [markdown]
# Rent Table for Project Comp257

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
plt.style.use('seaborn')
# %matplotlib inline

# %%
LGA = pd.read_excel('data/Rent-Tables-clean.xlsx', sheet_name= 0)

# %%
postcode = pd.read_excel('data/Rent-Tables-clean.xlsx', sheet_name=1)

# %%
LGA.shape
# Out:
# (33067, 15)

# %%
postcode.shape
# Out:
# (16481, 12)

# %%
LGA.replace(to_replace="-",value="",inplace=True)

# %%
LGA.head(100)
# Out:
#    GMR (Greater Metropolitan Region) Greater Sydney  Rings  \
# 0                              Total          Total  Total
# 1                              Total          Total  Total
# 2                              Total          Total  Total
# 3                              Total          Total  Total
# 4                              Total          Total  Total
# ..                               ...            ...    ...
# 95                             Total          Total  Total
# 96                             Total          Total  Total
# 97                             Total          Total  Total
# 98                             Total          Total  Total
# 99                             Total          Total  Total
#
#    LGA (Local Government Areas) Dwelling Types     Bedroom Numbers  \
# 0                         Total          Total               Total
# 1                         Total          Total           Bedsitter
# 2                         Total          Total           1 Bedroom
# 3                         Total          Total       Not Specified
# 4                         Total          Total          2 Bedrooms
# ..                          ...            ...                 ...
# 95            Armidale Regional      Townhouse  4 or more Bedrooms
# 96            Armidale Regional      Flat/Unit               Total
# 97            Armidale Regional      Flat/Unit           Bedsitter
# 98            Armidale Regional      Flat/Unit           1 Bedroom
# 99            Armidale Regional      Flat/Unit       Not Specified
#
#     First Quartile Weekly Rent for New Bonds\n$  \
# 0                                         375.0
# 1                                         315.0
# 2                                         340.0
# 3                                         350.0
# 4                                         360.0
# ..                                          ...
# 95                                          NaN
# 96                                        200.0
# 97                                          NaN
# 98                                        175.0
# 99                                          NaN
#
#     Median Weekly Rent for New Bonds\n$  \
# 0                                 475.0
# 1                                 390.0
# 2                                 450.0
# 3                                 440.0
# 4                                 465.0
# ..                                  ...
# 95                                  NaN
# 96                                250.0
# 97                                  NaN
# 98                                188.0
# 99                                  NaN
#
#     Third Quartile Weekly Rent for New Bonds\n$  New Bonds Lodged\nNo.  \
# 0                                         600.0                74871.0
# 1                                         465.0                  860.0
# 2                                         550.0                12637.0
# 3                                         560.0                 2796.0
# 4                                         610.0                27859.0
# ..                                          ...                    ...
# 95                                          NaN                    NaN
# 96                                        283.0                   96.0
# 97                                          NaN                    NaN
# 98                                        200.0                   30.0
# 99                                          NaN                    NaN
#
#     Total Bonds Held\nNo.  Quarterly change in Median Weekly Rent  \
# 0                764400.0                                 -0.0104
# 1                  8880.0                                 -0.0488
# 2                105243.0                                 -0.0217
# 3                 57312.0                                  0.0115
# 4                278716.0                                 -0.0510
# ..                    ...                                     ...
# 95                    NaN                                     NaN
# 96                 1263.0                                  0.0000
# 97                    NaN                                     NaN
# 98                  246.0                                 -0.0625
# 99                   50.0                                     NaN
#
#     Annual change in Median Weekly Rent  Quarterly change in New Bonds Lodged  \
# 0                               -0.0104                               -0.0778
# 1                                0.0000                               -0.1739
# 2                               -0.0217                               -0.1416
# 3                               -0.0414                               -0.0729
# 4                               -0.0312                               -0.0779
# ..                                  ...                                   ...
# 95                                  NaN                                   NaN
# 96                               0.0417                               -0.3846
# 97                                  NaN                                   NaN
# 98                              -0.0132                               -0.2000
# 99                                  NaN                                   NaN
#
#     Annual change in New Bonds Lodged
# 0                              0.0240
# 1                             -0.1088
# 2                              0.0235
# 3                             -0.2183
# 4                              0.0655
# ..                                ...
# 95                                NaN
# 96                            -0.1579
# 97                                NaN
# 98                            -0.2857
# 99                                NaN
#
# [100 rows x 15 columns]

# %%
LGA.dtypes
# Out:
# GMR (Greater Metropolitan Region)               object
# Greater Sydney                                  object
# Rings                                           object
# LGA (Local Government Areas)                    object
# Dwelling Types                                  object
# Bedroom Numbers                                 object
# First Quartile Weekly Rent for New Bonds\n$    float64
# Median Weekly Rent for New Bonds\n$            float64
# Third Quartile Weekly Rent for New Bonds\n$    float64
# New Bonds Lodged\nNo.                          float64
# Total Bonds Held\nNo.                          float64
# Quarterly change in Median Weekly Rent         float64
# Annual change in Median Weekly Rent            float64
# Quarterly change in New Bonds Lodged           float64
# Annual change in New Bonds Lodged              float64
# dtype: object

# %%
LGA.columns
# Out:
# Index(['GMR (Greater Metropolitan Region)', 'Greater Sydney', 'Rings',
#        'LGA (Local Government Areas)', 'Dwelling Types', 'Bedroom Numbers',
#        'First Quartile Weekly Rent for New Bonds\n$',
#        'Median Weekly Rent for New Bonds\n$',
#        'Third Quartile Weekly Rent for New Bonds\n$', 'New Bonds Lodged\nNo.',
#        'Total Bonds Held\nNo.', 'Quarterly change in Median Weekly Rent',
#        'Annual change in Median Weekly Rent',
#        'Quarterly change in New Bonds Lodged',
#        'Annual change in New Bonds Lodged'],
#       dtype='object')

# %%
LGA.rename(columns={'GMR (Greater Metropolitan Region)':'GMR',
                    'Greater Sydney':'Greater_Sydney',
                    'LGA (Local Government Areas)':'LGA',
                    'Dwelling Types':'Dwelling_Types',
                    'Bedroom Numbers':'Bedroom_Numbers'},
           inplace=True)

# %% [markdown]
# Column Renaming

# %%
LGA_clean =  LGA[LGA.Bedroom_Numbers != 'Total']

# %%
LGA_clean =  LGA_clean[LGA_clean.Dwelling_Types != 'Total']

# %%
LGA_clean = LGA_clean[LGA_clean.LGA != 'Total']

# %%
LGA_clean.shape
# Out:
# (20848, 15)

# %%
g = sns.pairplot(LGA_clean,vars=['First Quartile Weekly Rent for New Bonds\n$',
       'Median Weekly Rent for New Bonds\n$',
       'Third Quartile Weekly Rent for New Bonds\n$', 'New Bonds Lodged\nNo.',
       'Total Bonds Held\nNo.'],hue='Dwelling_Types')

# %%
g = sns.pairplot(LGA_clean,vars=['First Quartile Weekly Rent for New Bonds\n$',
       'Median Weekly Rent for New Bonds\n$',
       'Third Quartile Weekly Rent for New Bonds\n$', 'New Bonds Lodged\nNo.',
       'Total Bonds Held\nNo.'], hue='Bedroom_Numbers')

# %%
g = sns.pairplot(LGA_clean,vars=['First Quartile Weekly Rent for New Bonds\n$',
       'Median Weekly Rent for New Bonds\n$',
       'Third Quartile Weekly Rent for New Bonds\n$', 'New Bonds Lodged\nNo.',
       'Total Bonds Held\nNo.'], hue='Rings')

# %% [markdown]
# ### Data cleaning for Postcode

# %%
postcode.rename(columns={'Bedroom Numbers':'Bedroom_Numbers'}, inplace=True)

# %%
postcode.rename(columns={'Dwelling Types':'Dwelling_Types'}, inplace=True)

# %% [markdown]
# renaming columns for easy object referencing

# %%
postcode_clean =  postcode[postcode.Bedroom_Numbers != 'Total']

# %%
postcode_clean =  postcode_clean[postcode.Dwelling_Types != 'Total']
# Out:
# C:\Users\Hamza\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# basic data cleaning to remove totals as thet are a sum of other varibles

# %%
postcode_clean
# Out:
#        Postcode Dwelling_Types     Bedroom_Numbers  \
# 3          2739          House  4 or more Bedrooms
# 8          2307          Other           1 Bedroom
# 12         2641      Flat/Unit           1 Bedroom
# 14         2350          House           1 Bedroom
# 16         2710      Flat/Unit          2 Bedrooms
# ...         ...            ...                 ...
# 16464      4383      Flat/Unit          2 Bedrooms
# 16468      4385          House          2 Bedrooms
# 16472      4390          House  4 or more Bedrooms
# 16476      4703          House          3 Bedrooms
# 16480      5341          Other       Not Specified
#
#        First Quartile Weekly Rent for New Bonds\n$  \
# 3                                             95.0
# 8                                            125.0
# 12                                           133.0
# 14                                           135.0
# 16                                           140.0
# ...                                            ...
# 16464                                          NaN
# 16468                                          NaN
# 16472                                          NaN
# 16476                                          NaN
# 16480                                          NaN
#
#        Median Weekly Rent for New Bonds\n$  \
# 3                                    110.0
# 8                                    150.0
# 12                                   160.0
# 14                                   165.0
# 16                                   150.0
# ...                                    ...
# 16464                                  NaN
# 16468                                  NaN
# 16472                                  NaN
# 16476                                  NaN
# 16480                                  NaN
#
#        Third Quartile Weekly Rent for New Bonds\n$  New Bonds Lodged\nNo.  \
# 3                                            110.0                   30.0
# 8                                            190.0                   30.0
# 12                                           170.0                   30.0
# 14                                           200.0                   30.0
# 16                                           173.0                   30.0
# ...                                            ...                    ...
# 16464                                          NaN                    NaN
# 16468                                          NaN                    NaN
# 16472                                          NaN                    NaN
# 16476                                          NaN                    NaN
# 16480                                          NaN                    NaN
#
#        Total Bonds Held\nNo.  Quarterly change in Median Weekly Rent  \
# 3                       36.0                                  0.0000
# 8                       44.0                                 -0.2857
# 12                      66.0                                 -0.0857
# 14                      69.0                                  0.0313
# 16                     208.0                                  0.0000
# ...                      ...                                     ...
# 16464                    NaN                                     NaN
# 16468                    NaN                                     NaN
# 16472                    NaN                                     NaN
# 16476                    NaN                                     NaN
# 16480                    NaN                                     NaN
#
#        Annual change in Median Weekly Rent  \
# 3                                   0.0000
# 8                                   0.5000
# 12                                  0.0159
# 14                                 -0.0294
# 16                                 -0.0625
# ...                                    ...
# 16464                                  NaN
# 16468                                  NaN
# 16472                                  NaN
# 16476                                  NaN
# 16480                                  NaN
#
#        Quarterly change in New Bonds Lodged  Annual change in New Bonds Lodged
# 3                                    0.6923                             0.1000
# 8                                   -0.3478                             4.0000
# 12                                   0.2222                             1.7500
# 14                                  -0.3810                            -0.1333
# 16                                  -0.1579                            -0.2381
# ...                                     ...                                ...
# 16464                                   NaN                                NaN
# 16468                                   NaN                                NaN
# 16472                                   NaN                                NaN
# 16476                                   NaN                                NaN
# 16480                                   NaN                                NaN
#
# [10291 rows x 12 columns]

# %%
postcode_clean.columns
# Out:
# Index(['Postcode', 'Dwelling_Types', 'Bedroom_Numbers',
#        'First Quartile Weekly Rent for New Bonds\n$',
#        'Median Weekly Rent for New Bonds\n$',
#        'Third Quartile Weekly Rent for New Bonds\n$', 'New Bonds Lodged\nNo.',
#        'Total Bonds Held\nNo.', 'Quarterly change in Median Weekly Rent',
#        'Annual change in Median Weekly Rent',
#        'Quarterly change in New Bonds Lodged',
#        'Annual change in New Bonds Lodged'],
#       dtype='object')

# %%
g = sns.pairplot(postcode_clean,vars=['First Quartile Weekly Rent for New Bonds\n$',
       'Median Weekly Rent for New Bonds\n$',
       'Third Quartile Weekly Rent for New Bonds\n$', 'New Bonds Lodged\nNo.',
       'Total Bonds Held\nNo.'],hue='Dwelling_Types')

# %%
g = sns.pairplot(postcode_clean,vars=['First Quartile Weekly Rent for New Bonds\n$',
       'Median Weekly Rent for New Bonds\n$',
       'Third Quartile Weekly Rent for New Bonds\n$', 'New Bonds Lodged\nNo.',
       'Total Bonds Held\nNo.'],hue='Bedroom_Numbers')

# %%
dfNB= postcode_clean['New Bonds Lodged\nNo.']
dfNB.plot.hist()

# %%
postcode_clean.describe()
# Out:
#            Postcode  First Quartile Weekly Rent for New Bonds\n$  \
# count  10291.000000                                  1485.000000
# mean    2374.929550                                   471.542088
# std      278.292417                                   197.255138
# min     1360.000000                                    95.000000
# 25%     2142.000000                                   350.000000
# 50%     2320.000000                                   430.000000
# 75%     2570.000000                                   550.000000
# max     5341.000000                                  1875.000000
#
#        Median Weekly Rent for New Bonds\n$  \
# count                          1485.000000
# mean                            525.028956
# std                             233.315061
# min                             110.000000
# 25%                             378.000000
# 50%                             473.000000
# 75%                             610.000000
# max                            2225.000000
#
#        Third Quartile Weekly Rent for New Bonds\n$  New Bonds Lodged\nNo.  \
# count                                  1485.000000            1485.000000
# mean                                    584.544108              49.010774
# std                                     278.498330              48.298891
# min                                     110.000000              30.000000
# 25%                                     408.000000              30.000000
# 50%                                     519.000000              30.000000
# 75%                                     675.000000              43.000000
# max                                    3000.000000             544.000000
#
#        Total Bonds Held\nNo.  Quarterly change in Median Weekly Rent  \
# count            4134.000000                             1483.000000
# mean              176.235607                               -0.003885
# std               325.771549                                0.126409
# min                30.000000                               -0.350600
# 25%                39.000000                               -0.045650
# 50%                72.000000                               -0.005600
# 75%               162.000000                                0.023850
# max              5289.000000                                2.840000
#
#        Annual change in Median Weekly Rent  \
# count                          1483.000000
# mean                             -0.007564
# std                               0.083379
# min                              -0.450000
# 25%                              -0.051700
# 50%                              -0.010100
# 75%                               0.026350
# max                               0.688300
#
#        Quarterly change in New Bonds Lodged  Annual change in New Bonds Lodged
# count                           1483.000000                        1483.000000
# mean                               0.142599                           0.254852
# std                                0.695809                           0.697790
# min                               -0.863600                          -0.924200
# 25%                               -0.191000                          -0.083800
# 50%                                0.000000                           0.100000
# 75%                                0.285700                           0.382250
# max                               12.000000                          10.000000
